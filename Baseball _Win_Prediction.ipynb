# %% [markdown]
# # Baseball Winning Prediction:-

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy
import sklearn

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Importing the Dataset:-

# %%
data=pd.read_csv('Baseball.csv')
data
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# 11   86  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5
# 12   85  661  5417  1331  243  21  176  435  1150   52  675  630  3.94   2
# 13   76  656  5544  1379  262  22  198  478  1336   69  726  677  4.16   6
# 14   68  694  5600  1405  277  46  146  475  1119   78  729  664  4.14   5
# 15  100  647  5484  1386  288  39  137  506  1267   69  525  478  2.94   1
# 16   98  697  5631  1462  292  27  140  461  1322   98  596  532  3.21   0
# 17   97  689  5491  1341  272  30  171  567  1518   95  608  546  3.36   6
# 18   68  655  5480  1378  274  34  145  412  1299   84  737  682  4.28   1
# 19   64  640  5571  1382  257  27  167  496  1255  134  754  700  4.33   2
# 20   90  683  5527  1351  295  17  177  488  1290   51  613  557  3.43   1
# 21   83  703  5428  1363  265  13  177  539  1344   57  635  577  3.62   4
# 22   71  613  5463  1420  236  40  120  375  1150  112  678  638  4.02   0
# 23   67  573  5420  1361  251  18  100  471  1107   69  760  698  4.41   3
# 24   63  626  5529  1374  272  37  130  387  1274   88  809  749  4.69   1
# 25   92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26   84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27   79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28   74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29   68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV    E
# 0     8  56   88
# 1    12  45   86
# 2    10  38   79
# 3     9  37  101
# 4    12  35   86
# 5    10  34   88
# 6     4  48   93
# 7    10  43   77
# 8    12  60   95
# 9    10  40   97
# 10    9  45  119
# 11   13  39   85
# 12   12  46   93
# 13   12  45   94
# 14   15  28  126
# 15   15  62   96
# 16   13  54  122
# 17   21  48  111
# 18    7  40  116
# 19    8  35   90
# 20   14  50   88
# 21   13  41   90
# 22   12  35   77
# 23   10  44   90
# 24    7  35  117
# 25   21  47   75
# 26   18  41   78
# 27   12  44   86
# 28    6  41   92
# 29    4  36   95

# %%
data.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
data.shape
# Out:
# (30, 17)

# %%
data.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %% [markdown]
# # Data Cleaning:-

# %%
# Checking for the null values:-

data.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# Above observations shows that no null values are present in our data.

# %%
data.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %% [markdown]
# the column 'ERA' is a float type, rest of the columns are integer type. therefore, the complete data is numerical type.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
data=data.rename({'W':'No.of Wins'},axis=1)

# %%
data
# Out:
#     No.of Wins    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  \
# 0           95  724  5575  1497  300  42  139  383   973  104  641  601  3.73
# 1           83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07
# 2           81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67
# 3           76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98
# 4           74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64
# 5           93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80
# 6           87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03
# 7           81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05
# 8           80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74
# 9           78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31
# 10          88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24
# 11          86  729  5459  1363  278  26  230  486  1392  121  618  572  3.57
# 12          85  661  5417  1331  243  21  176  435  1150   52  675  630  3.94
# 13          76  656  5544  1379  262  22  198  478  1336   69  726  677  4.16
# 14          68  694  5600  1405  277  46  146  475  1119   78  729  664  4.14
# 15         100  647  5484  1386  288  39  137  506  1267   69  525  478  2.94
# 16          98  697  5631  1462  292  27  140  461  1322   98  596  532  3.21
# 17          97  689  5491  1341  272  30  171  567  1518   95  608  546  3.36
# 18          68  655  5480  1378  274  34  145  412  1299   84  737  682  4.28
# 19          64  640  5571  1382  257  27  167  496  1255  134  754  700  4.33
# 20          90  683  5527  1351  295  17  177  488  1290   51  613  557  3.43
# 21          83  703  5428  1363  265  13  177  539  1344   57  635  577  3.62
# 22          71  613  5463  1420  236  40  120  375  1150  112  678  638  4.02
# 23          67  573  5420  1361  251  18  100  471  1107   69  760  698  4.41
# 24          63  626  5529  1374  272  37  130  387  1274   88  809  749  4.69
# 25          92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44
# 26          84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72
# 27          79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04
# 28          74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09
# 29          68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04
#
#     CG  SHO  SV    E
# 0    2    8  56   88
# 1    2   12  45   86
# 2   11   10  38   79
# 3    7    9  37  101
# 4    7   12  35   86
# 5    7   10  34   88
# 6    3    4  48   93
# 7    0   10  43   77
# 8    1   12  60   95
# 9    3   10  40   97
# 10   5    9  45  119
# 11   5   13  39   85
# 12   2   12  46   93
# 13   6   12  45   94
# 14   5   15  28  126
# 15   1   15  62   96
# 16   0   13  54  122
# 17   6   21  48  111
# 18   1    7  40  116
# 19   2    8  35   90
# 20   1   14  50   88
# 21   4   13  41   90
# 22   0   12  35   77
# 23   3   10  44   90
# 24   1    7  35  117
# 25   6   21  47   75
# 26   7   18  41   78
# 27   1   12  44   86
# 28   1    6  41   92
# 29   4    4  36   95

# %%
data.describe()
# Out:
#        No.of Wins           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# min    13.000000  100.000000  375.000000   973.00000   44.000000  525.000000
# 25%    23.000000  140.250000  428.250000  1157.50000   69.000000  636.250000
# 50%    31.000000  158.500000  473.000000  1261.50000   83.500000  695.500000
# 75%    39.000000  177.000000  501.250000  1311.50000   96.500000  732.500000
# max    49.000000  232.000000  570.000000  1518.00000  134.000000  844.000000
#
#                ER        ERA         CG        SHO         SV           E
# count   30.000000  30.000000  30.000000  30.000000  30.000000   30.000000
# mean   635.833333   3.956333   3.466667  11.300000  43.066667   94.333333
# std     70.140786   0.454089   2.763473   4.120177   7.869335   13.958889
# min    478.000000   2.940000   0.000000   4.000000  28.000000   75.000000
# 25%    587.250000   3.682500   1.000000   9.000000  37.250000   86.000000
# 50%    644.500000   4.025000   3.000000  12.000000  42.000000   91.000000
# 75%    679.250000   4.220000   5.750000  13.000000  46.750000   96.750000
# max    799.000000   5.040000  11.000000  21.000000  62.000000  126.000000

# %% [markdown]
# # EDA:-

# %%
sns.heatmap(data.isnull())
plt.show()

# %%
data.columns
# Out:
# Index(['No.of Wins', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA',
#        'ER', 'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
sns.pairplot(data)
plt.show()

# %% [markdown]
# # Correlation:-

# %%
# Checking the Correlation with respect to target variable(Item_Outlet_Sales):-

data.corr()['No.of Wins'].sort_values()
# Out:
# ERA          -0.819600
# RA           -0.812952
# ER           -0.809435
# 3B           -0.251118
# SB           -0.157234
# E            -0.089485
# AB           -0.087947
# H             0.037612
# CG            0.080533
# SO            0.111850
# HR            0.307407
# 2B            0.427797
# R             0.430751
# SHO           0.471805
# BB            0.484342
# SV            0.666530
# No.of Wins    1.000000
# Name: No.of Wins, dtype: float64

# %%
plt.figure(figsize=(16,9))
sns.heatmap(data.corr(),annot=True,fmt='0.2f')
plt.show()

# %% [markdown]
# Above correlation shows that 'ERA','RA' and 'ER' has a strong negative correlation whereas '2B','R','SHO','BB' and 'SV' has a
# strong positive correlation.

# %% [markdown]
# # Reducing Multicollinearity with Variation Inflation Factor:-

# %%
import statsmodels.api as sm
import scipy.stats
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
x=data.drop(['No.of Wins'],axis=1)
x
# Out:
#       R   2B  3B   HR   BB    SO   SB  CG  SHO  SV    E
# 0   724  300  42  139  383   973  104   2    8  56   88
# 1   696  277  44  156  439  1264   70   2   12  45   86
# 2   669  303  29  141  533  1157   86  11   10  38   79
# 3   622  260  27  136  404  1231   68   7    9  37  101
# 4   689  289  49  151  455  1259   83   7   12  35   86
# 5   891  308  17  232  570  1151   88   7   10  34   88
# 6   764  272  19  212  554  1227   63   3    4  48   93
# 7   713  246  20  217  418  1331   44   0   10  43   77
# 8   644  278  32  167  436  1310   87   1   12  60   95
# 9   748  294  33  161  478  1148   71   3   10  40   97
# 10  751  279  32  172  503  1233  101   5    9  45  119
# 11  729  278  26  230  486  1392  121   5   13  39   85
# 12  661  243  21  176  435  1150   52   2   12  46   93
# 13  656  262  22  198  478  1336   69   6   12  45   94
# 14  694  277  46  146  475  1119   78   5   15  28  126
# 15  647  288  39  137  506  1267   69   1   15  62   96
# 16  697  292  27  140  461  1322   98   0   13  54  122
# 17  689  272  30  171  567  1518   95   6   21  48  111
# 18  655  274  34  145  412  1299   84   1    7  40  116
# 19  640  257  27  167  496  1255  134   2    8  35   90
# 20  683  295  17  177  488  1290   51   1   14  50   88
# 21  703  265  13  177  539  1344   57   4   13  41   90
# 22  613  236  40  120  375  1150  112   0   12  35   77
# 23  573  251  18  100  471  1107   69   3   10  44   90
# 24  626  272  37  130  387  1274   88   1    7  35  117
# 25  667  263  26  187  563  1258   59   6   21  47   75
# 26  696  288  39  136  457  1159   93   7   18  41   78
# 27  720  289  48  154  490  1312  132   1   12  44   86
# 28  650  260  36  148  426  1327   82   1    6  41   92
# 29  737  274  49  186  388  1283   97   4    4  36   95

# %%
y=data['No.of Wins']
y
# Out:
# 0      95
# 1      83
# 2      81
# 3      76
# 4      74
# 5      93
# 6      87
# 7      81
# 8      80
# 9      78
# 10     88
# 11     86
# 12     85
# 13     76
# 14     68
# 15    100
# 16     98
# 17     97
# 18     68
# 19     64
# 20     90
# 21     83
# 22     71
# 23     67
# 24     63
# 25     92
# 26     84
# 27     79
# 28     74
# 29     68
# Name: No.of Wins, dtype: int64

# %%
x.shape
# Out:
# (30, 16)

# %%
x.shape[1]
# Out:
# 16

# %%
def calc_vif(x):
    vif=pd.DataFrame()
    vif['VIF FACTOR']=[variance_inflation_factor(x.values,i) for i in range(x.shape[1])]
    vif['Features']=x.columns
    print(vif)

# %%
calc_vif(x)
# Out:
#       VIF FACTOR Features
# 0    1638.985029        R
# 1    4277.157018       AB
# 2    4698.798408        H
# 3     904.439835       2B
# 4      32.435486       3B
# 5     285.773237       HR
# 6     269.485018       BB
# 7     398.234104       SO
# 8      28.654970       SB
# 9   17204.829356       RA
# 10  49837.289228       ER
# 11  23551.544014      ERA
# 12      6.771036       CG
# 13     30.276598      SHO
# 14    119.686080       SV
# 15     94.215202        E

# %% [markdown]
# Therefore, the above observations shows that 'AB','H','ER','ERA','RA' so, we will drop them.

# %%
data=data.drop(['AB','H','E','CG'],axis=1)
data
# Out:
#     No.of Wins    R   2B  3B   HR   BB    SO   SB   RA   ER   ERA  SHO  SV
# 0           95  724  300  42  139  383   973  104  641  601  3.73    8  56
# 1           83  696  277  44  156  439  1264   70  700  653  4.07   12  45
# 2           81  669  303  29  141  533  1157   86  640  584  3.67   10  38
# 3           76  622  260  27  136  404  1231   68  701  643  3.98    9  37
# 4           74  689  289  49  151  455  1259   83  803  746  4.64   12  35
# 5           93  891  308  17  232  570  1151   88  670  609  3.80   10  34
# 6           87  764  272  19  212  554  1227   63  698  652  4.03    4  48
# 7           81  713  246  20  217  418  1331   44  693  646  4.05   10  43
# 8           80  644  278  32  167  436  1310   87  642  604  3.74   12  60
# 9           78  748  294  33  161  478  1148   71  753  694  4.31   10  40
# 10          88  751  279  32  172  503  1233  101  733  680  4.24    9  45
# 11          86  729  278  26  230  486  1392  121  618  572  3.57   13  39
# 12          85  661  243  21  176  435  1150   52  675  630  3.94   12  46
# 13          76  656  262  22  198  478  1336   69  726  677  4.16   12  45
# 14          68  694  277  46  146  475  1119   78  729  664  4.14   15  28
# 15         100  647  288  39  137  506  1267   69  525  478  2.94   15  62
# 16          98  697  292  27  140  461  1322   98  596  532  3.21   13  54
# 17          97  689  272  30  171  567  1518   95  608  546  3.36   21  48
# 18          68  655  274  34  145  412  1299   84  737  682  4.28    7  40
# 19          64  640  257  27  167  496  1255  134  754  700  4.33    8  35
# 20          90  683  295  17  177  488  1290   51  613  557  3.43   14  50
# 21          83  703  265  13  177  539  1344   57  635  577  3.62   13  41
# 22          71  613  236  40  120  375  1150  112  678  638  4.02   12  35
# 23          67  573  251  18  100  471  1107   69  760  698  4.41   10  44
# 24          63  626  272  37  130  387  1274   88  809  749  4.69    7  35
# 25          92  667  263  26  187  563  1258   59  595  553  3.44   21  47
# 26          84  696  288  39  136  457  1159   93  627  597  3.72   18  41
# 27          79  720  289  48  154  490  1312  132  713  659  4.04   12  44
# 28          74  650  260  36  148  426  1327   82  731  655  4.09    6  41
# 29          68  737  274  49  186  388  1283   97  844  799  5.04    4  36

# %%
data.shape
# Out:
# (30, 13)

# %% [markdown]
# # Checking for the Skewness:-

# %%
data.skew()
# Out:
# No.of Wins    0.047089
# R             1.200786
# 2B           -0.230650
# 3B            0.129502
# HR            0.516441
# BB            0.158498
# SO           -0.156065
# SB            0.479893
# RA            0.045734
# ER            0.058710
# ERA           0.053331
# SHO           0.565790
# SV            0.657524
# dtype: float64

# %% [markdown]
# Above data shows that 'SO','SB','CG' and 'E' are highly skewed.

# %%
# checking with the distribution curve:-

sns.distplot(data['2B'])
plt.show()

# %%
sns.distplot(data['3B'])
plt.show()

# %%
sns.distplot(data['HR'])
plt.show()

# %%
sns.distplot(data['BB'])
plt.show()

# %%
sns.distplot(data['SO'])
plt.show()

# %%
sns.distplot(data['SB'])
plt.show()

# %%
sns.distplot(data['RA'])
plt.show()

# %%
sns.distplot(data['SHO'])
plt.show()

# %%
sns.distplot(data['ER'])
plt.show()

# %%
sns.distplot(data['ERA'])
plt.show()

# %%
sns.distplot(data['No.of Wins'])
plt.show()

# %%
sns.distplot(data['R'])
plt.show()

# %%
sns.distplot(data['SHO'])
plt.show()

# %%
sns.distplot(data['SV'])
plt.show()

# %% [markdown]
# Above visualizations shows that the is not normalized.
# The building blocks is out of normalized curve.

# %% [markdown]
# # Outliers Removal:-

# %%
# checking the outliers with visualization:-

data.plot(kind='box',subplots=True,layout=(4,4),figsize=(20,16),grid=True)
plt.show()

# %%
from scipy.stats import zscore
z=np.abs(zscore(data))
z
# Out:
# array([[1.36540860e+00, 6.19077968e-01, 1.42017307e+00, 1.04119304e+00,
#         7.87298598e-01, 1.53490242e+00, 2.69762957e+00, 9.13883291e-01,
#         6.66233927e-01, 5.05110079e-01, 5.06955186e-01, 8.14628593e-01,
# 18          68  655  274  34  145  412  1299   84  737  682  4.28    7  40
# 19          64  640  257  27  167  496  1255  134  754  700  4.33    8  35
# 20          90  683  295  17  177  488  1290   51  613  557  3.43   14  50
# 21          83  703  265  13  177  539  1344   57  635  577  3.62   13  41
# 22          71  613  236  40  120  375  1150  112  678  638  4.02   12  35
# 23          67  573  251  18  100  471  1107   69  760  698  4.41   10  44
# 24          63  626  272  37  130  387  1274   88  809  749  4.69    7  35
# 25          92  667  263  26  187  563  1258   59  595  553  3.44   21  47
# 26          84  696  288  39  136  457  1159   93  627  597  3.72   18  41
# 27          79  720  289  48  154  490  1312  132  713  659  4.04   12  44
# 28          74  650  260  36  148  426  1327   82  731  655  4.09    6  41
# 29          68  737  274  49  186  388  1283   97  844  799  5.04    4  36

# %%
# Transforming the data to remove skewness:-

import sklearn
from sklearn.preprocessing import power_transform
X=power_transform(data,method='yeo-johnson')
X
# Out:
# array([[ 1.34694657,  0.72821775,  1.47768528,  1.03310301, -0.76462586,
#         -1.61091476, -2.56989562,  0.93970819, -0.66033096, -0.49742469,
#         -0.50089346, -0.78957937,  1.546378  ],
#        [ 0.21865782,  0.26121202,  0.08426878,  1.2033202 , -0.15858141,
#         -0.50274883,  0.13491294, -0.53969308,  0.17546536,  0.25797351,
#          0.26180619,  0.25177537,  0.36044386],
#        [ 0.02527078, -0.24482102,  1.67078208, -0.16026987, -0.68967629,
#          1.1282937 , -0.90125379,  0.2119555 , -0.67462053, -0.74690639,
#         -0.63645949, -0.24539345, -0.6075936 ],
#        [-0.46557388, -1.28512888, -0.84859969, -0.36052064, -0.8790486 ,
#         -1.18120722, -0.1896282 , -0.64256433,  0.18951225,  0.11357524,
#          0.06080381, -0.51075929, -0.76445333],
#        [-0.6650169 ,  0.13562216,  0.79218291,  1.61644394, -0.3298501 ,
#         -0.20677062,  0.08545863,  0.07962852,  1.6032282 ,  1.5826538 ,
#          1.52095856,  0.25177537, -1.09501024],
#        [ 1.16248603,  2.67190261,  1.99850636, -1.4610616 ,  1.93785984,
#          1.7080669 , -0.95796004,  0.29823789, -0.24775668, -0.38046418,
#         -0.34310973, -0.24539345, -1.26943834],
#        [ 0.60066773,  1.30968823, -0.19855793, -1.22491064,  1.46009864,
#          1.46112104, -0.22866778, -0.91015416,  0.14736005,  0.24355176,
#          0.17254893, -2.09932639,  0.71808189],
#        [ 0.02527078,  0.55119925, -1.55645436, -1.11030224,  1.58355136,
#         -0.90445022,  0.80717417, -2.10289743,  0.07702925,  0.15693705,
#          0.2171929 , -0.24539345,  0.10460573],
#        [-0.07204101, -0.77026607,  0.1416866 ,  0.130611  ,  0.20005848,
#         -0.55919142,  0.59456066,  0.25528505, -0.64604565, -0.45353173,
#         -0.47832824,  0.25177537,  1.90547983],
#        [-0.26793573,  1.08809602,  1.09940491,  0.2252559 ,  0.00740376,
#          0.20459864, -0.98625666, -0.4890904 ,  0.9148155 ,  0.84591008,
#          0.79482258, -0.24539345, -0.30910856],
#        [ 0.69521353,  1.13070855,  0.1993895 ,  0.130611  ,  0.35550255,
#         -1.15897488,  2.1228587 ,  0.60212705],
#        [ 0.31474635,  0.26121202,  0.73160797,  0.77187241, -0.8790486 ,
#         -0.17035471, -0.88231827,  0.50760474, -0.86077652, -0.55601027,
#         -0.52346697,  1.55042485, -0.16691871],
#        [-0.16977414,  0.66477061,  0.79218291,  1.53515592, -0.22643599,
#          0.41304265,  0.61473509,  1.9006571 ,  0.35777783,  0.34442049,
#          0.19487476,  0.25177537,  0.23438459],
#        [-0.6650169 , -0.63870172, -0.84859969,  0.5028866 , -0.43529176,
#         -0.749579  ,  0.76654332,  0.03471274,  0.60916531,  0.28680506,
#          0.30638893, -1.39754579, -0.16691871],
#        [-1.27484954,  0.92744475, -0.08627816,  1.61644394,  0.76831413,
#         -1.50694503,  0.3237498 ,  0.6690207 ,  2.16161235,  2.324072  ,
#          2.39132405, -2.09932639, -0.92680917]])

# %%
X.ndim
# Out:
# 2

# %%
X.std()
# Out:
# 1.0

# %%
x=data_new.drop(['No.of Wins'],axis=1)
x
# Out:
#       R   2B  3B   HR   BB    SO   SB   RA   ER   ERA  SHO  SV
# 0   724  300  42  139  383   973  104  641  601  3.73    8  56
# 1   696  277  44  156  439  1264   70  700  653  4.07   12  45
# 2   669  303  29  141  533  1157   86  640  584  3.67   10  38
# 3   622  260  27  136  404  1231   68  701  643  3.98    9  37
# 4   689  289  49  151  455  1259   83  803  746  4.64   12  35
# 6   764  272  19  212  554  1227   63  698  652  4.03    4  48
# 7   713  246  20  217  418  1331   44  693  646  4.05   10  43
# 8   644  278  32  167  436  1310   87  642  604  3.74   12  60
# 9   748  294  33  161  478  1148   71  753  694  4.31   10  40
# 10  751  279  32  172  503  1233  101  733  680  4.24    9  45
# 11  729  278  26  230  486  1392  121  618  572  3.57   13  39
# 12  661  243  21  176  435  1150   52  675  630  3.94   12  46
# 13  656  262  22  198  478  1336   69  726  677  4.16   12  45
# 14  694  277  46  146  475  1119   78  729  664  4.14   15  28
# 15  647  288  39  137  506  1267   69  525  478  2.94   15  62
# 16  697  292  27  140  461  1322   98  596  532  3.21   13  54
# 17  689  272  30  171  567  1518   95  608  546  3.36   21  48
# 18  655  274  34  145  412  1299   84  737  682  4.28    7  40
# 19  640  257  27  167  496  1255  134  754  700  4.33    8  35
# 20  683  295  17  177  488  1290   51  613  557  3.43   14  50
# 21  703  265  13  177  539  1344   57  635  577  3.62   13  41
# 22  613  236  40  120  375  1150  112  678  638  4.02   12  35
# 23  573  251  18  100  471  1107   69  760  698  4.41   10  44
# 24  626  272  37  130  387  1274   88  809  749  4.69    7  35
# 25  667  263  26  187  563  1258   59  595  553  3.44   21  47
# 26  696  288  39  136  457  1159   93  627  597  3.72   18  41
# 27  720  289  48  154  490  1312  132  713  659  4.04   12  44
# 28  650  260  36  148  426  1327   82  731  655  4.09    6  41
# 29  737  274  49  186  388  1283   97  844  799  5.04    4  36

# %%
y=data_new['No.of Wins']
y
# Out:
# 0      95
# 1      83
# 2      81
# 3      76
# 4      74
# 6      87
# 7      81
# 8      80
# 9      78
# 10     88
# 11     86
# 12     85
# 13     76
# 14     68
# 15    100
# 16     98
# 17     97
# 18     68
# 19     64
# 20     90
# 21     83
# 22     71
# 23     67
# 24     63
# 25     92
# 26     84
# 27     79
# 28     74
# 29     68
# Name: No.of Wins, dtype: int64

# %% [markdown]
# # Preprocessing:-

# %%
import sklearn
from sklearn.preprocessing import StandardScaler

scaler=StandardScaler()
x_scaled=scaler.fit_transform(x)

# %% [markdown]
# # Machine Learning Algorithms Training and Testing Process:-

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score,mean_squared_error as mse,mean_absolute_error as mae

# %%
# linear Regression;

lr=LinearRegression()

for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,test_size=0.2,random_state=i)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    train_accuracy=r2_score(y_train,pred_train)
    test_accuracy=r2_score(y_test,pred_test)
    print("At random state train",{i},train_accuracy)
    print("At random state test",{i},test_accuracy)
    print("\n")
    print('Mean-squared-error: ',mse(y_test,pred_test))
    print('Mean-absolute-error: ',mae(y_test,pred_test))
    print('Root-Mean-squared-error: ',np.sqrt(mse(y_test,pred_test)))
    print('R2 SCore: ',r2_score(y_test,pred_test))
# Out:
# At random state train {0} 0.9488287804850776
# At random state test {0} 0.4911451197069855
#
#
# Mean-squared-error:  37.4291034171084
# Mean-absolute-error:  4.533033404651607
# Root-Mean-squared-error:  6.117932936630509
# R2 SCore:  0.4911451197069855
# At random state train {1} 0.9053113844087192
# At random state test {1} 0.8459122276621371
#
#
# Mean-squared-error:  21.52092553652152
# Mean-absolute-error:  3.8286866453611856
# Root-Mean-squared-error:  4.6390651576068125
# R2 SCore:  0.8459122276621371
# At random state train {2} 0.9281729610267953
# At random state test {2} -0.35345629522872746
#
#
# Mean-squared-error:  52.07047135810521
# Mean-absolute-error:  6.114966617561383
# Root-Mean-squared-error:  7.215987206065793
# R2 SCore:  -0.35345629522872746
# At random state train {3} 0.9085228052851868
# At random state test {3} 0.8786412808918566
#
#
# Mean-squared-error:  20.819762478108164
# Mean-absolute-error:  4.217129546641583
# Root-Mean-squared-error:  4.56286779099594
# R2 SCore:  0.8786412808918566
# At random state train {4} 0.918598498700604
# At random state test {4} 0.8070704330140687
#
#
# Mean-squared-error:  17.068907523616424
# Mean-absolute-error:  3.565838802081968
# Root-Mean-squared-error:  4.131453439604085
# R2 SCore:  0.8070704330140687
# At random state train {5} 0.9307166316529074
# At random state test {5} 0.6123846748572765
#
#
# Mean-squared-error:  27.832933763720565
# Mean-absolute-error:  4.855004509773541
# Root-Mean-squared-error:  5.275692728326828
# R2 SCore:  0.6123846748572765
# At random state train {6} 0.9083383167088862
# At random state test {6} 0.8313163451329325
#
#
# Mean-squared-error:  25.044837090679888
# Mean-absolute-error:  4.030520458966573
# Root-Mean-squared-error:  5.004481700504048
# R2 SCore:  0.8313163451329325
# At random state train {7} 0.9331665817840268
# At random state test {7} 0.515991045931472
#
#
# Mean-squared-error:  21.619066615060916
# Mean-absolute-error:  4.292869840792207
# Root-Mean-squared-error:  4.649630804167242
# R2 SCore:  0.515991045931472
# At random state train {8} 0.9386626577557916
# At random state test {8} 0.7512863163537267
#
#
# Mean-squared-error:  39.662923828145985
# Mean-absolute-error:  4.749974055460595
# Root-Mean-squared-error:  6.297850730856201
# R2 SCore:  0.7512863163537267
# At random state train {9} 0.9730545103156852
# At random state test {9} 0.14179372675952695
#
#
# Mean-squared-error:  57.33294686509271
# Mean-absolute-error:  7.026691587236985
# Root-Mean-squared-error:  7.571852274383905
# R2 SCore:  0.14179372675952695
# At random state train {10} 0.9575072567812548
# At random state test {10} 0.03326240393823221
#
#
# Mean-squared-error:  49.948109129858004
# Mean-absolute-error:  5.534012170790336
# Root-Mean-squared-error:  7.067397620755323
# R2 SCore:  0.03326240393823221
# At random state train {11} 0.9432957797847359
# At random state test {11} 0.3893302768426876
#
#
# Mean-squared-error:  32.857423715436504
# Mean-absolute-error:  5.096105737636307
# Root-Mean-squared-error:  5.732139540820382
# R2 SCore:  0.3893302768426876
# At random state train {12} 0.9448527292552602
# At random state test {12} 0.5009130963782249
#
#
# Mean-squared-error:  35.6015324583533
# Mean-absolute-error:  4.489198079971025
# Root-Mean-squared-error:  5.966701974990313
# R2 SCore:  0.5009130963782249
# At random state train {13} 0.9109018515023388
# At random state test {13} 0.8960972346786289
#
#
# Mean-squared-error:  8.058236688257445
# Mean-absolute-error:  2.1974114448075404
# Root-Mean-squared-error:  2.8387033462934173
# R2 SCore:  0.8960972346786289
# At random state train {14} 0.9315722343311955
# At random state test {14} 0.734210642761636
#
#
# Mean-squared-error:  14.529818195697233
# Mean-absolute-error:  3.225920207005094
# Root-Mean-squared-error:  3.811799863017107
# R2 SCore:  0.734210642761636
# At random state train {15} 0.8993491028344874
# At random state test {15} 0.8797532919848955
#
#
# Mean-squared-error:  19.76054235048218
# Mean-absolute-error:  3.721085263987952
# Root-Mean-squared-error:  4.445283157514511
# R2 SCore:  0.8797532919848955
# At random state train {16} 0.9501755994334357
# At random state test {16} 0.19703954117763245
#
#
# Mean-squared-error:  47.753842842741356
# Mean-absolute-error:  5.953157945260261
# Root-Mean-squared-error:  6.910415533290408
# R2 SCore:  0.19703954117763245
# At random state train {17} 0.9173255539444769
# At random state test {17} 0.7407142220279314
#
#
# Mean-squared-error:  32.29548412296543
# Mean-absolute-error:  4.976133319352994
# Root-Mean-squared-error:  5.6829115885226855
# R2 SCore:  0.7407142220279314
# At random state train {18} 0.9659095684374587
# At random state test {18} 0.048848613275099484
#
#
# Mean-squared-error:  68.79995030643447
# Mean-absolute-error:  7.467410486655434
# Root-Mean-squared-error:  8.294573545784887
# R2 SCore:  0.048848613275099484
# At random state train {19} 0.941349943292141
# At random state test {19} 0.40402222020421685
#
#
# Mean-squared-error:  39.6656322330749
# Mean-absolute-error:  4.483913622813557
# Root-Mean-squared-error:  6.298065753314655
# R2 SCore:  0.40402222020421685
# At random state train {20} 0.9496047069558491
# At random state test {20} 0.1840621539995534
#
#
# Mean-squared-error:  38.19042418085424
# Mean-absolute-error:  5.043121982840328
# Root-Mean-squared-error:  6.179840142014536
# R2 SCore:  0.1840621539995534
# At random state train {21} 0.9413272623455216
# At random state test {21} 0.6075427732283527
#
#
# Mean-squared-error:  26.38184691076074
# Mean-absolute-error:  3.60599482204074
# Root-Mean-squared-error:  5.136326207588527
# R2 SCore:  0.6075427732283527
# At random state train {22} 0.9089837123494415
# At random state test {22} 0.7547635882548078
#
#
# Mean-squared-error:  18.86276733673437
# Mean-absolute-error:  3.8921878432848396
# Root-Mean-squared-error:  4.343128749730356
# R2 SCore:  0.7547635882548078
# At random state train {23} 0.9457547469664069
# At random state test {23} 0.368403591423627
#
#
# Mean-squared-error:  42.738023647001235
# Mean-absolute-error:  5.626537764885874
# Root-Mean-squared-error:  6.537432496554074
# R2 SCore:  0.368403591423627
# At random state train {24} 0.9331501603558873
# At random state test {24} -0.6419760601376499
#
#
# Mean-squared-error:  32.15536451102898
# Mean-absolute-error:  4.906601674328435
# Root-Mean-squared-error:  5.670570034046752
# R2 SCore:  -0.6419760601376499
# At random state train {25} 0.9283802294887036
# At random state test {25} 0.5564050887216834
#
#
# Mean-squared-error:  16.26514674687161
# Mean-absolute-error:  3.5559380063978927
# Root-Mean-squared-error:  4.033007159288415
# R2 SCore:  0.5564050887216834
# At random state train {26} 0.92982158993478
# At random state test {26} 0.7426911996732601
#
#
# Mean-squared-error:  16.503500554290067
# Mean-absolute-error:  3.4654798591126856
# Root-Mean-squared-error:  4.062450067913459
# R2 SCore:  0.7426911996732601
# At random state train {27} 0.9502340528653627
# At random state test {27} 0.6461241729975782
#
#
# Mean-squared-error:  31.229541732963725
# Mean-absolute-error:  4.546055564471312
# Root-Mean-squared-error:  5.588339801136266
# R2 SCore:  0.6461241729975782
# At random state train {28} 0.9579324196750644
# At random state test {28} 0.29581342838888913
#
#
# Mean-squared-error:  53.90939420445059
# Mean-absolute-error:  5.318466482198417
# Root-Mean-squared-error:  7.3423016966378185
# R2 SCore:  0.29581342838888913
# At random state train {29} 0.9248347156658748
# At random state test {29} 0.8263540771582554
#
#
# Mean-squared-error:  20.470924903899
# Mean-absolute-error:  4.3117839824496045
# Root-Mean-squared-error:  4.524480622557577
# R2 SCore:  0.8263540771582554
# At random state train {30} 0.9045064175021018
# At random state test {30} 0.7409491050116073
#
#
# Mean-squared-error:  37.101844848893144
# Mean-absolute-error:  5.559606885197638
# Root-Mean-squared-error:  6.091128372386609
# R2 SCore:  0.7409491050116073
# At random state train {31} 0.9502539556999419
# At random state test {31} 0.16210334767384038
#
#
# Mean-squared-error:  41.17331049902712
# Mean-absolute-error:  5.826660769143662
# Root-Mean-squared-error:  6.416643242305677
# R2 SCore:  0.16210334767384038
# At random state train {32} 0.9551791487501753
# At random state test {32} 0.38544463605074475
#
#
# Mean-squared-error:  56.67566134198688
# Mean-absolute-error:  6.476212701354814
# Root-Mean-squared-error:  7.528323939761551
# R2 SCore:  0.38544463605074475
# At random state train {33} 0.9349568316893959
# At random state test {33} 0.42279501952876686
#
#
# Mean-squared-error:  45.55109304218815
# Mean-absolute-error:  5.996384865732573
# Root-Mean-squared-error:  6.749154987269751
# R2 SCore:  0.42279501952876686
# At random state train {34} 0.9520988775975652
# At random state test {34} 0.40646965353108966
#
#
# Mean-squared-error:  38.727855107096396
# Mean-absolute-error:  4.868165469427848
# Root-Mean-squared-error:  6.2231708241937564
# R2 SCore:  0.40646965353108966
# At random state train {35} 0.9521518513073709
# At random state test {35} 0.7221035238173727
#
#
# Mean-squared-error:  43.50623721570242
# Mean-absolute-error:  5.674827394792213
# Root-Mean-squared-error:  6.5959258042902835
# R2 SCore:  0.7221035238173727
# At random state train {36} 0.8890602219927064
# At random state test {36} 0.6204817990581737
#
#
# Mean-squared-error:  31.078323788236215
# Mean-absolute-error:  4.73014293775972
# Root-Mean-squared-error:  5.574793609474365
# R2 SCore:  0.6204817990581737
# At random state train {37} 0.9524809226236091
# At random state test {37} 0.15732445031543307
#
#
# Mean-squared-error:  38.03743800659503
# Mean-absolute-error:  5.196190318694228
# Root-Mean-squared-error:  6.167449878725812
# R2 SCore:  0.15732445031543307
# At random state train {38} 0.9327984895639995
# At random state test {38} 0.15590139255184676
#
#
# Mean-squared-error:  50.2942086937858
# Mean-absolute-error:  5.355614985704167
# Root-Mean-squared-error:  7.0918409946773195
# R2 SCore:  0.15590139255184676
# At random state train {39} 0.9507541839854203
# At random state test {39} 0.4306926341471966
#
#
# Mean-squared-error:  45.68691610968747
# Mean-absolute-error:  5.513645873800428
# Root-Mean-squared-error:  6.75920972523323
# R2 SCore:  0.4306926341471966
# At random state train {40} 0.9380676699335296
# At random state test {40} 0.44034453249684735
#
#
# Mean-squared-error:  72.00900348540564
# Mean-absolute-error:  6.619303116640026
# Root-Mean-squared-error:  8.48581189311934
# R2 SCore:  0.44034453249684735
# At random state train {41} 0.9085759220715945
# At random state test {41} 0.851064950266217
#
#
# Mean-squared-error:  12.349197873759508
# Mean-absolute-error:  3.1052852331972054
# Root-Mean-squared-error:  3.5141425517129363
# R2 SCore:  0.851064950266217
# At random state train {42} 0.9278237910591851
# At random state test {42} 0.6963508334401176
#
#
# Mean-squared-error:  29.251536378601998
# Mean-absolute-error:  4.287601933572795
# Root-Mean-squared-error:  5.408468949582867
# R2 SCore:  0.6963508334401176
# At random state train {43} 0.9659142182507746
# At random state test {43} -0.10601217042725763
#
#
# Mean-squared-error:  56.19156276976262
# Mean-absolute-error:  5.76131703920795
# Root-Mean-squared-error:  7.496103172299766
# R2 SCore:  -0.10601217042725763
# At random state train {44} 0.9361625406600828
# At random state test {44} 0.4077308539592126
#
#
# Mean-squared-error:  29.613457302039368
# Mean-absolute-error:  5.042943530681515
# Root-Mean-squared-error:  5.441824813611641
# R2 SCore:  0.4077308539592126
# At random state train {45} 0.953874479862008
# At random state test {45} 0.4036927958777219
#
#
# Mean-squared-error:  36.7060212315269
# Mean-absolute-error:  5.0680067092205405
# Root-Mean-squared-error:  6.058549432952321
# R2 SCore:  0.4036927958777219
# At random state train {46} 0.9224176146191593
# At random state test {46} 0.8140922417458252
#
#
# Mean-squared-error:  11.304224522733023
# Mean-absolute-error:  2.969490576201314
# Root-Mean-squared-error:  3.3621755639366935
# R2 SCore:  0.8140922417458252
# At random state train {47} 0.9048599198162774
# At random state test {47} 0.9301733206051218
#
#
# Mean-squared-error:  8.813678643620177
# Mean-absolute-error:  1.8570147833042039
# Root-Mean-squared-error:  2.968784034519887
# R2 SCore:  0.9301733206051218
# At random state train {48} 0.9597703752298492
# At random state test {48} 0.39307176827063395
#
#
# Mean-squared-error:  50.50991617392168
# Mean-absolute-error:  5.502733662760018
# Root-Mean-squared-error:  7.107032867091701
# R2 SCore:  0.39307176827063395
# At random state train {49} 0.906931146450614
# At random state test {49} 0.2293645171375578
#
#
# Mean-squared-error:  59.70284338064865
# Mean-absolute-error:  6.3909771500860515
# Root-Mean-squared-error:  7.726761506650031
# R2 SCore:  0.2293645171375578
# At random state train {50} 0.9125538386770278
# At random state test {50} 0.8324109526077583
#
#
# Mean-squared-error:  10.651215012040254
# Mean-absolute-error:  3.0040107270171603
# Root-Mean-squared-error:  3.263619924568462
# R2 SCore:  0.8324109526077583
# At random state train {51} 0.9590512350949661
# At random state test {51} 0.3679370140588758
#
#
# Mean-squared-error:  52.40855591761821
# Mean-absolute-error:  6.1001113856950155
# Root-Mean-squared-error:  7.239375381731369
# R2 SCore:  0.3679370140588758
# At random state train {52} 0.9621359668878333
# At random state test {52} -0.064257684829778
#
#
# Mean-squared-error:  49.45841963111718
# Mean-absolute-error:  6.160453784630898
# Root-Mean-squared-error:  7.032668030777308
# R2 SCore:  -0.064257684829778
# At random state train {53} 0.9387050361835567
# At random state test {53} 0.582885612591871
#
#
# Mean-squared-error:  36.90303677485809
# Mean-absolute-error:  5.750606062352833
# Root-Mean-squared-error:  6.074786973619576
# R2 SCore:  0.582885612591871
# At random state train {54} 0.9338795138127773
# At random state test {54} 0.5046803906587053
#
#
# Mean-squared-error:  15.464978913878204
# Mean-absolute-error:  3.4017042341034744
# Root-Mean-squared-error:  3.9325537394774663
# R2 SCore:  0.5046803906587053
# At random state train {55} 0.9459660967770039
# At random state test {55} 0.25078790588961086
#
#
# Mean-squared-error:  54.79654010535151
# Mean-absolute-error:  6.9138778238241825
# Root-Mean-squared-error:  7.4024685143100415
# R2 SCore:  0.25078790588961086
# At random state train {56} 0.952992802816634
# At random state test {56} 0.3405866689443152
#
#
# Mean-squared-error:  40.9752117103213
# Mean-absolute-error:  5.106880330224047
# Root-Mean-squared-error:  6.401188304551062
# R2 SCore:  0.3405866689443152
# At random state train {57} 0.9539835199349485
# At random state test {57} 0.7367957664073996
#
#
# Mean-squared-error:  37.11179693655666
# Mean-absolute-error:  5.076047719922357
# Root-Mean-squared-error:  6.091945250620417
# R2 SCore:  0.7367957664073996
# At random state train {58} 0.95460952110794
# At random state test {58} 0.6372369828136373
#
#
# Mean-squared-error:  32.12468052194791
# Mean-absolute-error:  4.9001261341276745
# Root-Mean-squared-error:  5.667863841161669
# R2 SCore:  0.6372369828136373
# At random state train {59} 0.9441287110359394
# At random state test {59} 0.39879091049312754
#
#
# Mean-squared-error:  32.14798603613137
# Mean-absolute-error:  4.6687777968808675
# Root-Mean-squared-error:  5.669919402966093
# R2 SCore:  0.39879091049312754
# At random state train {60} 0.9756897668313211
# At random state test {60} 0.34295954992380073
#
#
# Mean-squared-error:  64.04319275881619
# Mean-absolute-error:  7.662254441519536
# Root-Mean-squared-error:  8.002699092107374
# R2 SCore:  0.34295954992380073
# At random state train {61} 0.9464775269288812
# At random state test {61} 0.5119353383211764
#
#
# Mean-squared-error:  52.99568784729225
# Mean-absolute-error:  5.4412750774095615
# Root-Mean-squared-error:  7.279813723392396
# R2 SCore:  0.5119353383211764
# At random state train {62} 0.9470852336457151
# At random state test {62} 0.47957081719810135
#
#
# Mean-squared-error:  37.71665938694871
# Mean-absolute-error:  5.26189845332559
# Root-Mean-squared-error:  6.1413890437708565
# R2 SCore:  0.47957081719810135
# At random state train {63} 0.9727976528449189
# At random state test {63} 0.4304771117509948
#
#
# Mean-squared-error:  52.285365157304504
# Mean-absolute-error:  6.500411398664501
# Root-Mean-squared-error:  7.23086199268832
# R2 SCore:  0.4304771117509948
# At random state train {64} 0.926439373495586
# At random state test {64} 0.5326136185038521
#
#
# Mean-squared-error:  54.63227481488306
# Mean-absolute-error:  6.812051281210546
# Root-Mean-squared-error:  7.391364881730779
# R2 SCore:  0.5326136185038521
# At random state train {65} 0.9466198451420871
# At random state test {65} 0.6514589440678598
#
#
# Mean-squared-error:  40.05317634420177
# Mean-absolute-error:  4.473693659728911
# Root-Mean-squared-error:  6.328757883202814
# R2 SCore:  0.6514589440678598
# At random state train {66} 0.9312765386091337
# At random state test {66} 0.752424687675385
#
#
# Mean-squared-error:  17.000171446290235
# Mean-absolute-error:  3.5534875343591303
# Root-Mean-squared-error:  4.123126416481822
# R2 SCore:  0.752424687675385
# At random state train {67} 0.9135507048982197
# At random state test {67} 0.8483788550842626
#
#
# Mean-squared-error:  24.36046394979515
# Mean-absolute-error:  4.407287637014843
# Root-Mean-squared-error:  4.9356320719635445
# R2 SCore:  0.8483788550842626
# At random state train {68} 0.917611948706782
# At random state test {68} 0.7841889479802172
#
#
# Mean-squared-error:  17.91231731764197
# Mean-absolute-error:  3.4478796310589885
# Root-Mean-squared-error:  4.23229456886474
# R2 SCore:  0.7841889479802172
# At random state train {69} 0.8701204307374002
# At random state test {69} 0.9764947787641953
#
#
# Mean-squared-error:  3.680525891839741
# Mean-absolute-error:  1.5798869338372181
# Root-Mean-squared-error:  1.918469674464452
# R2 SCore:  0.9764947787641953
# At random state train {70} 0.951886739009756
# At random state test {70} 0.359202070072446
#
#
# Mean-squared-error:  44.143857395009285
# Mean-absolute-error:  5.329203063643807
# Root-Mean-squared-error:  6.644084391021029
# R2 SCore:  0.359202070072446
# At random state train {71} 0.9778701985886792
# At random state test {71} -2.358765852339427
#
#
# Mean-squared-error:  62.41706542264102
# Mean-absolute-error:  6.810898104996492
# Root-Mean-squared-error:  7.900447165992633
# R2 SCore:  -2.358765852339427
# At random state train {72} 0.9329461777496887
# At random state test {72} 0.543699774201369
#
#
# Mean-squared-error:  13.600281730053645
# Mean-absolute-error:  2.866843819236543
# Root-Mean-squared-error:  3.687855980112787
# R2 SCore:  0.543699774201369
# At random state train {73} 0.9167671882558063
# At random state test {73} 0.7806366823732637
#
#
# Mean-squared-error:  29.15704096788703
# Mean-absolute-error:  3.9366623986267038
# Root-Mean-squared-error:  5.39972600859405
# R2 SCore:  0.7806366823732637
# At random state train {74} 0.9419167515064379
# At random state test {74} -0.5723990160884977
#
#
# Mean-squared-error:  51.19032352376999
# Mean-absolute-error:  5.456762927968501
# Root-Mean-squared-error:  7.154741331716332
# R2 SCore:  -0.5723990160884977
# At random state train {75} 0.9052481933028175
# At random state test {75} 0.8968462498907125
#
#
# Mean-squared-error:  13.940083174491214
# Mean-absolute-error:  3.079688585900115
# Root-Mean-squared-error:  3.7336420790551434
# R2 SCore:  0.8968462498907125
# At random state train {76} 0.9620293854523732
# At random state test {76} 0.572962016267049
#
#
# Mean-squared-error:  61.588366987263385
# Mean-absolute-error:  6.408377663291103
# Root-Mean-squared-error:  7.847825621614142
# R2 SCore:  0.572962016267049
# At random state train {77} 0.9354195450971607
# At random state test {77} 0.6105309383371051
#
#
# Mean-squared-error:  21.810267453122112
# Mean-absolute-error:  4.418621823422545
# Root-Mean-squared-error:  4.670146405962249
# R2 SCore:  0.6105309383371051
# At random state train {78} 0.9354156598487033
# At random state test {78} 0.1979607788511385
#
#
# Mean-squared-error:  66.74748629338858
# Mean-absolute-error:  6.9923662755167895
# Root-Mean-squared-error:  8.169913481389418
# R2 SCore:  0.1979607788511385
# At random state train {79} 0.9356481169139413
# At random state test {79} 0.7009704684909108
#
#
# Mean-squared-error:  38.11795889153361
# Mean-absolute-error:  4.576633411212337
# Root-Mean-squared-error:  6.173974318988832
# R2 SCore:  0.7009704684909108
# At random state train {80} 0.9483502752758292
# At random state test {80} 0.4443524749822413
#
#
# Mean-squared-error:  62.86534359437031
# Mean-absolute-error:  5.904275855101439
# Root-Mean-squared-error:  7.928766839450527
# R2 SCore:  0.4443524749822413
# At random state train {81} 0.9580743690311206
# At random state test {81} 0.685922532717179
#
#
# Mean-squared-error:  37.02624364300812
# Mean-absolute-error:  5.64842302972313
# Root-Mean-squared-error:  6.084919362079346
# R2 SCore:  0.685922532717179
# At random state train {82} 0.9221359855209466
# At random state test {82} 0.7075179950313193
#
#
# Mean-squared-error:  21.391808863403778
# Mean-absolute-error:  3.9104903981378905
# Root-Mean-squared-error:  4.625127983462055
# R2 SCore:  0.7075179950313193
# At random state train {83} 0.9388058333632839
# At random state test {83} 0.6043060462664934
#
#
# Mean-squared-error:  44.8013487616048
# Mean-absolute-error:  4.934522014489367
# Root-Mean-squared-error:  6.693380966417854
# R2 SCore:  0.6043060462664934
# At random state train {84} 0.9369128223111394
# At random state test {84} 0.5781357526204192
#
#
# Mean-squared-error:  21.046338563714645
# Mean-absolute-error:  4.1668218949319495
# Root-Mean-squared-error:  4.587628860720388
# R2 SCore:  0.5781357526204192
# At random state train {85} 0.922934675502641
# At random state test {85} 0.8008997199098573
#
#
# Mean-squared-error:  25.84432246836769
# Mean-absolute-error:  4.342845942403183
# Root-Mean-squared-error:  5.083731156185158
# R2 SCore:  0.8008997199098573
# At random state train {86} 0.9177419712275088
# At random state test {86} 0.6239441655914961
#
#
# Mean-squared-error:  14.46770362932716
# Mean-absolute-error:  3.305523294123686
# Root-Mean-squared-error:  3.803643467693464
# R2 SCore:  0.6239441655914961
# At random state train {87} 0.910260697684046
# At random state test {87} 0.8861842054168572
#
#
# Mean-squared-error:  5.71924367780293
# Mean-absolute-error:  1.8062999022596884
# Root-Mean-squared-error:  2.391494026294636
# R2 SCore:  0.8861842054168572
# At random state train {88} 0.9875783277518173
# At random state test {88} -1.4946743593110123
#
#
# Mean-squared-error:  109.55778227974196
# Mean-absolute-error:  8.319603609643082
# Root-Mean-squared-error:  10.466985348214736
# R2 SCore:  -1.4946743593110123
# At random state train {89} 0.9224785477185278
# At random state test {89} 0.6544225429460226
#
#
# Mean-squared-error:  28.10696650705682
# Mean-absolute-error:  3.9149239068765667
# Root-Mean-squared-error:  5.30160037225146
# R2 SCore:  0.6544225429460226
# At random state train {90} 0.9124143324037595
# At random state test {90} 0.8859547008418313
#
#
# Mean-squared-error:  7.048633072970154
# Mean-absolute-error:  2.0763788314921237
# Root-Mean-squared-error:  2.6549261897405274
# R2 SCore:  0.8859547008418313
# At random state train {91} 0.9669828954703338
# At random state test {91} 0.4333200371675564
#
#
# Mean-squared-error:  63.16907474573878
# Mean-absolute-error:  7.534133931008661
# Root-Mean-squared-error:  7.9478975047328575
# R2 SCore:  0.4333200371675564
# At random state train {92} 0.9356253413146841
# At random state test {92} 0.6144115841223243
#
#
# Mean-squared-error:  27.848052257832137
# Mean-absolute-error:  3.457621534235784
# Root-Mean-squared-error:  5.277125378255868
# R2 SCore:  0.6144115841223243
# At random state train {93} 0.9408571198539608
# At random state test {93} 0.41939401154784217
#
#
# Mean-squared-error:  38.449018790831786
# Mean-absolute-error:  5.7202471740688905
# Root-Mean-squared-error:  6.200727279185224
# R2 SCore:  0.41939401154784217
# At random state train {94} 0.9438068246769767
# At random state test {94} 0.3534774882530475
#
#
# Mean-squared-error:  38.71951487017861
# Mean-absolute-error:  5.49193115760162
# Root-Mean-squared-error:  6.222500692661963
# R2 SCore:  0.3534774882530475
# At random state train {95} 0.9133862307459697
# At random state test {95} 0.7807620349219917
#
#
# Mean-squared-error:  31.399748553950293
# Mean-absolute-error:  5.072217814373881
# Root-Mean-squared-error:  5.603547854167955
# R2 SCore:  0.7807620349219917
# At random state train {96} 0.9698490407831563
# At random state test {96} 0.14814110816330883
#
#
# Mean-squared-error:  105.91445555169527
# Mean-absolute-error:  8.83112427095269
# Root-Mean-squared-error:  10.291474896811208
# R2 SCore:  0.14814110816330883
# At random state train {97} 0.9208726451318776
# At random state test {97} 0.8009709240535156
#
#
# Mean-squared-error:  22.84964363574501
# Mean-absolute-error:  4.14606083011213
# Root-Mean-squared-error:  4.780130085650914
# R2 SCore:  0.8009709240535156
# At random state train {98} 0.9508447525609204
# At random state test {98} 0.4771015548740971
#
#
# Mean-squared-error:  69.66169285621753
# Mean-absolute-error:  6.640030911930213
# Root-Mean-squared-error:  8.346358059430324
# R2 SCore:  0.4771015548740971
# At random state train {99} 0.9088104115371036
# At random state test {99} 0.8824685466227328
#
#
# Mean-squared-error:  17.93007616522087
# Mean-absolute-error:  3.446989775913669
# Root-Mean-squared-error:  4.234392065600548
# R2 SCore:  0.8824685466227328

# %%
print('Best accuracy is ',0.878, 'on random_state',4)
# Out:
# Best accuracy is  0.878 on random_state 4

# %%
# Choosing the best random state in linear regression

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=4)

# %%
# Linear Regression;

lr=LinearRegression()

lr.fit(x_train,y_train)
predlr=lr.predict(x_test)
print("R2 Score",r2_score(y_test,predlr)*100)
print('Mean-squared-error: ',mse(y_test,predlr))
print('Mean-absolute-error: ',mae(y_test,predlr))
print('Root-Mean-squared-error: ',np.sqrt(mse(y_test,predlr)))
# Out:
# R2 Score 80.70704330140677
# Mean-squared-error:  17.068907523616513
# Mean-absolute-error:  3.565838802081982
# Root-Mean-squared-error:  4.131453439604096

# %%
#Support vector regressor;


from sklearn.svm import SVR
 
svr=SVR(kernel='linear')
svr.fit(x_train,y_train)
pred_svr=svr.predict(x_test)
print("R2 Score",r2_score(y_test,pred_svr)*100)
print('Mean-squared-error: ',mse(y_test,pred_svr))
print('Mean-absolute-error: ',mae(y_test,pred_svr))
print('Root-Mean-squared-error: ',np.sqrt(mse(y_test,pred_svr)))
# Out:
# R2 Score 58.63648681646425
# Mean-squared-error:  36.595219302655934
# Mean-absolute-error:  5.6286111330325825
# Root-Mean-squared-error:  6.049398259550774

# %%
# Decision tree regressor;

from sklearn.tree import DecisionTreeRegressor
 
dtr=DecisionTreeRegressor()
dtr.fit(x_train,y_train)
pred_dtr=dtr.predict(x_test)
print("R2 Score",r2_score(y_test,pred_dtr)*100)
print('Mean-squared-error: ',mse(y_test,pred_dtr))
print('Mean-absolute-error: ',mae(y_test,pred_dtr))
print('Root-Mean-squared-error: ',np.sqrt(mse(y_test,pred_dtr)))
# Out:
# R2 Score 67.03296703296704
# Mean-squared-error:  29.166666666666668
# Mean-absolute-error:  4.833333333333333
# Root-Mean-squared-error:  5.400617248673217

# %%
# Random Forest Regressor;

from sklearn.ensemble import RandomForestRegressor

rf=RandomForestRegressor(n_estimators=100)
rf.fit(x_train,y_train)
predrf=rf.predict(x_test)
print("R2 Score",r2_score(y_test,predrf)*100)
print('Mean-squared-error: ',mse(y_test,predrf))
print('Mean-absolute-error: ',mae(y_test,predrf))
print('Root-Mean-squared-error: ',np.sqrt(mse(y_test,predrf)))
# Out:
# R2 Score 73.85763265306122
# Mean-squared-error:  23.12873333333334
# Mean-absolute-error:  3.856666666666667
# Root-Mean-squared-error:  4.809234173268478

# %%
# Ada Boost Regressor;

from sklearn.ensemble import AdaBoostRegressor

ad=AdaBoostRegressor(n_estimators=100)
ad.fit(x_train,y_train)
pred_ad=ad.predict(x_test)
print("R2 Score",r2_score(y_test,pred_ad)*100)
print('Mean-squared-error: ',mse(y_test,pred_ad))
print('Mean-absolute-error: ',mae(y_test,pred_ad))
print('Root-Mean-squared-error: ',np.sqrt(mse(y_test,pred_ad)))
# Out:
# R2 Score 88.89586603872318
# Mean-squared-error:  9.824074074074078
# Mean-absolute-error:  2.7777777777777786
# Root-Mean-squared-error:  3.134337900430341

# %% [markdown]
# Therefore, Adaboost Regressor shows the metrics results among other models.

# %%
# Cross Validation for linear regression;

from sklearn.model_selection import cross_val_score

#validation accuracy
cv_score=cross_val_score(lr,x,y,cv=9)
print('Cross validation score of Linear Regression model:',cv_score)
print('Mean of Cross validation score:',cv_score.mean())
print("R2 Score",r2_score(y_test,predlr)*100)
# Out:
# Cross validation score of Linear Regression model: [  0.37433202  -1.26640971  -0.13386725  -0.38458977 -27.40722577
#    0.93562331   0.51735627   0.96142603   0.44759964]
# Mean of Cross validation score: -2.88397280424947
# R2 Score 80.70704330140677

# %%
# Cross Validation for support vector regression;

cv_score=cross_val_score(svr,x,y,cv=9)
print('Cross validation support vector Regression model:',cv_score)
print('Mean of Cross validation score:',cv_score.mean())
print("R2 Score",r2_score(y_test,pred_svr)*100)
# Out:
# Cross validation support vector Regression model: [ 1.86917097e-01 -2.16060409e+00 -1.19469537e-02 -1.57654864e+00
#  -4.09433205e+01  9.26265721e-01  6.27817115e-01  9.66096007e-01
#  -4.77654829e-01]
# Mean of Cross validation score: -4.718108782607663
# R2 Score 58.63648681646425

# %%
# Cross Validation for decision tree regression;

cv_score=cross_val_score(dtr,x,y,cv=9)
print('Cross validation score of decision tree Regression model:',cv_score)
print('Mean of Cross validation score:',cv_score.mean())
print("R2 Score",r2_score(y_test,pred_dtr)*100)
# Out:
# Cross validation score of decision tree Regression model: [  0.35301669  -4.30588235  -6.875        0.35023041 -39.5
#    0.89540816  -1.09134615   0.83283804  -7.52197802]
# Mean of Cross validation score: -6.318079247117655
# R2 Score 67.03296703296704

# %%
# Cross Validation for random forest regression;

cv_score=cross_val_score(rf,x,y,cv=9)
print('Cross validation score of random forest Regression model:',cv_score)
print('Mean of Cross validation score:',cv_score.mean())
print("R2 Score",r2_score(y_test,predrf)*100)
# Out:
# Cross validation score of random forest Regression model: [ 3.58147882e-01 -6.60082353e-01 -3.81181071e+00  1.27929724e-01
#  -8.85945286e+01  7.44071173e-01  7.06742788e-02  9.31308024e-01
#   3.50592308e-01]
# Mean of Cross validation score: -10.053744249941253
# R2 Score 73.85763265306122

# %%
# Cross Validation for AdaBoost regression;

cv_score=cross_val_score(ad,x,y,cv=9)
print('Cross validation score of AdaBoost Regression model:',cv_score)
print('Mean of Cross validation score:',cv_score.mean())
print("R2 Score",r2_score(y_test,pred_ad)*100)
# Out:
# Cross validation score of AdaBoost Regression model: [  0.12865497  -2.34150327  -2.80732143   0.11423963 -92.52262889
#    0.56631352   0.22275641   0.92143388   0.50729739]
# Mean of Cross validation score: -10.578973087443126
# R2 Score 88.89586603872318

# %% [markdown]
# Therefore the difference between cv score and r2 score in very less in case of AdaBoost Regressor that is [0.92-0.88=0.04],So we will choose this model for further process.

# %% [markdown]
# # Hyperparameter Tuning:-

# %%
AdaBoostRegressor()
# Out:
# AdaBoostRegressor()

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import AdaBoostRegressor

parameters={'loss':['linear','square','exponential'],
            'learning_rate':[0.001,0.01,0.1],
            'random_state':[1,4,5,9],
            'n_estimators':[100,200,300,400]}
ad=AdaBoostRegressor()
clf=GridSearchCV(ad,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'learning_rate': 0.1, 'loss': 'square', 'n_estimators': 200, 'random_state': 9}

# %%
ad=AdaBoostRegressor(loss='square',learning_rate=0.1,random_state=9,n_estimators=200)
ad.fit(x_train,y_train)
train_r2=ad.score(x_train,y_train)
pred_decision=ad.predict(x_test)
print(train_r2)
ad2=r2_score(y_test,pred_decision)
print('R2_Score',ad2)
ads=cross_val_score(ad,x,y,cv=5)
adc=ad.score(x_train,y_train)
print('Cross_Val_Score',adc*100)
# Out:
# 0.9866110243837745
# R2_Score 0.8619439046685268
# Cross_Val_Score 98.66110243837744

# %% [markdown]
# So, we are getting our model accuracy(R2 Score) 86% with
# an Cross_Val_score 98.6% in our model.

# %% [markdown]
# # Saving the Model:-

# %%
import pickle
filename='Baseball_Win.pkl'
pickle.dump(ad,open(filename,'wb'))

# %% [markdown]
# # Conclusion:-

# %%
loaded_model=pickle.load(open('Baseball_Win.pkl','rb'))

# %%
conclusion=pd.DataFrame([loaded_model.predict(x_test)[:],pred_decision[:]],
                        index=['Predicted','Original'])
conclusion
# Out:
#                    0          1          2     3          4     5
# Predicted  80.142857  77.285714  75.333333  96.0  83.636364  90.0
# Original   80.142857  77.285714  75.333333  96.0  83.636364  90.0

# %%
conclusion.transpose()
# Out:
#    Predicted   Original
# 0  80.142857  80.142857
# 1  77.285714  77.285714
# 2  75.333333  75.333333
# 3  96.000000  96.000000
# 4  83.636364  83.636364
# 5  90.000000  90.000000
